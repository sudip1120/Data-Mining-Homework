# %%
import pandas as pd
from datetime import datetime

# %%
df= pd.read_csv('BKB_WaterQualityData_2020084.csv')

# %%
df
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 0        Bay     NaN    1/3/1994             1.3                     11.7
# 1        Bay     NaN   1/31/1994             1.5                     12.0
# 2        Bay     NaN    2/7/1994             1.0                     10.5
# 3        Bay     NaN   2/23/1994             1.0                     10.1
# 4        Bay     NaN   2/28/1994             1.0                     12.6
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
# t= df[(df['Read_Date'] >= '1/1/1998') & (df['Read_Date'] <= '12/31/2018')]
t=df.query("Year >=1998 and Year <= 2018")

# %%
t
# Out:
#      Site_Id Unit_Id   Read_Date  Salinity (ppt)  Dissolved Oxygen (mg/L)  \
# 330      Bay     NaN    1/4/1998             1.5                     12.3
# 331      Bay     NaN   1/25/1998             1.2                     12.5
# 332      Bay     NaN   2/22/1998             1.1                     10.7
# 333      Bay     NaN   3/22/1998             1.0                     11.1
# 334      Bay     NaN   4/19/1998             1.0                     10.8
# ...      ...     ...         ...             ...                      ...
# 2366     Bay     NaN  10/11/2018             1.9                      5.0
# 2367     Bay     NaN  10/24/2018             0.0                      9.0
# 2368     Bay     NaN  10/28/2018             0.9                      2.9
# 2369     Bay     NaN   11/7/2018             1.7                      NaN
# 2370     Bay     NaN  12/11/2018             0.1                      NaN
#
#       pH (standard units)  Secchi Depth (m)  Water Depth (m)  Water Temp (?C)  \
# ...

# %%
t.to_csv('back_bay_1998-2018_clean.csv')

# %%
print(len(df.columns))
# Out:
# 17

# %%
print(t.columns)
# Out:
# Index(['Site_Id', 'Unit_Id', 'Read_Date', 'Salinity (ppt)',
#        'Dissolved Oxygen (mg/L)', 'pH (standard units)', 'Secchi Depth (m)',
#        'Water Depth (m)', 'Water Temp (?C)', 'Air Temp-Celsius',
#        'Air Temp (?F)', 'Time (24:00)', 'Field_Tech', 'DateVerified',
#        'WhoVerified', 'AirTemp (C)', 'Year'],
#       dtype='object')

# %%
t_mean = df["Dissolved Oxygen (mg/L)"].mean()

# %%
t_mean
# Out:
# 6.646263157894744

# %%
column = t["AirTemp (C)"]
max_value = column.max()
max_value
# Out:
# 33.0

# %%
t['AirTemp (C)'].min()
# Out:
# -17.77777778

# %%
t.iloc[:, [2]].min()
# Out:
# Read_Date    1/10/2002
# dtype: object

# %%
t["Year"].value_counts()
# Out:
# 2009    120
# 2004    119
# 2006    118
# 2008    117
# 2001    115
# 2007    114
# 2010    109
# 2000    109
# 2002    108
# 2005    107
# 2003     98
# 2011     97
# 2013     91
# 2012     88
# 2015     88
# 2014     87
# 2017     85
# 2018     82
# 2016     59
# 1999     45
# 1998     15
# Name: Year, dtype: int64

# %%
salinity_BySite =t[['Salinity (ppt)','Site_Id']]

# %%
print("Bay", salinity_BySite.query("Site_Id == 'Bay'").mean())
print("A", salinity_BySite.query("Site_Id == 'A'").mean())
print("B", salinity_BySite.query("Site_Id == 'B'").mean())
print("C", salinity_BySite.query("Site_Id == 'C'").mean())
print("D", salinity_BySite.query("Site_Id == 'D'").mean())
print("d", salinity_BySite.query("Site_Id == 'd'").mean())
# Out:
# Bay Salinity (ppt)    0.650556
# dtype: float64
# A Salinity (ppt)    0.334135
# dtype: float64
# B Salinity (ppt)    0.444838
# dtype: float64
# C Salinity (ppt)    0.596397
# dtype: float64
# D Salinity (ppt)    0.103483
# dtype: float64
# d Salinity (ppt)    0.0
# dtype: float64

# %% [markdown]
# 2. When looking at the mean ppt, which location would you infer is furthest from the influence of ocean water
# inflows?

# %% [markdown]
# ### Answer:
# As per the above data, area 'D' with mean ppt 0.103483 is the location which is furthest from the influence of ocean water.

# %% [markdown]
# 3. Dig a little deeper into #2, and write why there may be some uncertainty in your answer? (hint: certainty
# is improved by consistency in data)

# %% [markdown]
# ### Answer:
#
# The data we have is unconsistence. on August 11, salinity ppt for Site D was .02. Again after 7 day later ppt level is 3 for the same site. This is a massive changes. It is hard to make decission based on the given data

# %% [markdown]
# 4. Use the data to determine the correlation between Salinity (ppt) and pH (standard units). Use the
# DataFrame.corr(). You just need to report the correlation value

# %%
column_1 = t["Salinity (ppt)"]
column_2 = t["pH (standard units)"]
correlation = column_1.corr(column_2)
print(correlation)
# Out:
# 0.26930634452336155
